# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3361, in _wrap_pool_connect
#     return fn()
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 310, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 868, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 476, in checkout
#     rec = pool._do_get()
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
# ...

# %%
query = """
SELECT * FROM yellow_taxi_2021_08 LIMIT 100;
"""
pd.read_sql(query, con=engine)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3361, in _wrap_pool_connect
#     return fn()
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 310, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 868, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 476, in checkout
#     rec = pool._do_get()
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#   File "/home/kelan/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
# ...
